# %%
def convert_fasta_to_single_line(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        sequence = ""
        header = None
        for line in infile:
            line = line.strip()
            if line.startswith(">"):
                if header is not None:
                    outfile.write(header + "\n" + sequence + "\n")
                header = line
                sequence = ""
            else:
                sequence += line
        if header is not None:
            outfile.write(header + "\n" + sequence + "\n")

# Actual file paths
input_path = r"C:\Users\sanch\Downloads\multiline_input.fasta"
output_path = r"C:\Users\sanch\Downloads\multiline_input.fasta"

# Calling the function
convert_fasta_to_single_line(input_path, output_path)

print("Conversion successful! Output saved at:", output_path)
# Out:
# Conversion successful! Output saved at: C:\Users\sanch\Downloads\multiline_input.fasta
